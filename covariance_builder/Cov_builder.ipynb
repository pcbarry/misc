# %%
import numpy as np
import pandas as pd

# %%
tab=pd.read_excel('../../database/dy_qT/expdata/30001.xlsx')

# %%
pd.DataFrame(tab)
# Out:
#        RS   Q  Qmin  Qmax     y  ymin  ymax      qT  qTmin  qTmax  ...  \
# 0   13000  91    60   120  3.25     2   4.5    1.10    0.0    2.2  ...
# 1   13000  91    60   120  3.25     2   4.5    2.80    2.2    3.4  ...
# 2   13000  91    60   120  3.25     2   4.5    4.00    3.4    4.6  ...
# 3   13000  91    60   120  3.25     2   4.5    5.20    4.6    5.8  ...
# 4   13000  91    60   120  3.25     2   4.5    6.50    5.8    7.2  ...
# 5   13000  91    60   120  3.25     2   4.5    7.95    7.2    8.7  ...
# 6   13000  91    60   120  3.25     2   4.5    9.60    8.7   10.5  ...
# 7   13000  91    60   120  3.25     2   4.5   11.65   10.5   12.8  ...
# 8   13000  91    60   120  3.25     2   4.5   14.10   12.8   15.4  ...
# 9   13000  91    60   120  3.25     2   4.5   17.20   15.4   19.0  ...
# 10  13000  91    60   120  3.25     2   4.5   21.75   19.0   24.5  ...
# 11  13000  91    60   120  3.25     2   4.5   29.25   24.5   34.0  ...
# 12  13000  91    60   120  3.25     2   4.5   48.50   34.0   63.0  ...
# 13  13000  91    60   120  3.25     2   4.5  166.50   63.0  270.0  ...
#
#     kCut2[GeV]  pTmin  etaMin  etaMax   col  beam  target  \
# 0           20     20       2     4.5  LHCb     p       p
# 1           20     20       2     4.5  LHCb     p       p
# 2           20     20       2     4.5  LHCb     p       p
# 3           20     20       2     4.5  LHCb     p       p
# 4           20     20       2     4.5  LHCb     p       p
# 5           20     20       2     4.5  LHCb     p       p
# 6           20     20       2     4.5  LHCb     p       p
# 7           20     20       2     4.5  LHCb     p       p
# 8           20     20       2     4.5  LHCb     p       p
# 9           20     20       2     4.5  LHCb     p       p
# 10          20     20       2     4.5  LHCb     p       p
# 11          20     20       2     4.5  LHCb     p       p
# 12          20     20       2     4.5  LHCb     p       p
# 13          20     20       2     4.5  LHCb     p       p
#
#                 process       obs   units
# 0   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 1   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 2   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 3   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 4   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 5   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 6   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 7   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 8   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 9   pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 10  pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 11  pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 12  pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
# 13  pp->Z/gamma*->l+ l-  dsig/dpT  pb/GeV
#
# [14 rows x 40 columns]

# %%
print(tab.keys())
# Out:
# Index(['RS', 'Q', 'Qmin', 'Qmax', 'y', 'ymin', 'ymax', 'qT', 'qTmin', 'qTmax',
#        'value', 'stat_u', 'syst_c', 'norm_c', 'cov_0_S', 'cov_1_S', 'cov_2_S',
#        'cov_3_S', 'cov_4_S', 'cov_5_S', 'cov_6_S', 'cov_7_S', 'cov_8_S',
#        'cov_9_S', 'cov_10_S', 'cov_11_S', 'cov_12_S', 'cov_13_S',
#        'FiducialCuts', 'kCut1[GeV]', 'kCut2[GeV]', 'pTmin', 'etaMin', 'etaMax',
#        'col', 'beam', 'target', 'process', 'obs', 'units'],
#       dtype='object')

# %%
# print(tab['idx'])

# %%
syst=tab['syst_u'].values
stat=tab['stat_u'].values

# %%
print(stat)
# Out:
# [0.11   0.21   0.21   0.21   0.18   0.16   0.13   0.11   0.09   0.07
#  0.05   0.029  0.011  0.0009]

# %%
corr=pd.read_excel('HEPData-ins1477581-v1-Table_12.xlsx')

# %%
cov=[]
for i in range(len(syst)):
    cov.append([])
    for j in range(len(syst)):
        cov[i].append(0)

# %%
print(len(cov[0]))
# Out:
# 14

# %%
for i in range(len(corr['Bin index'])):
    idx1=corr['Bin index'][i]-1
    idx2=corr['Bin index.1'][i]-1
    cov[idx1][idx2]=corr['Correlation'][i]

# %%
print(cov)
# Out:
# [[1.0, 0.54, 0.54, 0.53, 0.55, 0.54, 0.53, 0.52, 0.51, 0.53, 0.53, 0.53, 0.54, 0.42], [0.54, 1.0, 0.55, 0.54, 0.55, 0.56, 0.53, 0.54, 0.52, 0.54, 0.55, 0.56, 0.55, 0.44], [0.54, 0.55, 1.0, 0.55, 0.55, 0.56, 0.54, 0.55, 0.54, 0.55, 0.57, 0.57, 0.57, 0.45], [0.53, 0.54, 0.55, 1.0, 0.56, 0.55, 0.55, 0.55, 0.55, 0.55, 0.56, 0.56, 0.58, 0.47], [0.55, 0.55, 0.55, 0.56, 1.0, 0.56, 0.56, 0.55, 0.55, 0.57, 0.56, 0.56, 0.58, 0.47], [0.54, 0.56, 0.56, 0.55, 0.56, 1.0, 0.54, 0.55, 0.53, 0.54, 0.56, 0.56, 0.56, 0.44], [0.53, 0.53, 0.54, 0.55, 0.56, 0.54, 1.0, 0.54, 0.55, 0.55, 0.55, 0.55, 0.58, 0.47], [0.52, 0.54, 0.55, 0.55, 0.55, 0.55, 0.54, 1.0, 0.55, 0.55, 0.57, 0.58, 0.58, 0.48], [0.51, 0.52, 0.54, 0.55, 0.55, 0.53, 0.55, 0.55, 1.0, 0.56, 0.57, 0.57, 0.6, 0.5], [0.53, 0.54, 0.55, 0.55, 0.57, 0.54, 0.55, 0.55, 0.56, 1.0, 0.56, 0.57, 0.59, 0.49], [0.53, 0.55, 0.57, 0.56, 0.56, 0.56, 0.55, 0.57, 0.57, 0.56, 1.0, 0.6, 0.6, 0.5], [0.53, 0.56, 0.57, 0.56, 0.56, 0.56, 0.55, 0.58, 0.57, 0.57, 0.6, 1.0, 0.61, 0.51], [0.54, 0.55, 0.57, 0.58, 0.58, 0.56, 0.58, 0.58, 0.6, 0.59, 0.6, 0.61, 1.0, 0.54], [0.42, 0.44, 0.45, 0.47, 0.47, 0.44, 0.47, 0.48, 0.5, 0.49, 0.5, 0.51, 0.54, 1.0]]

# Out:
#           0         1         2         3         4         5         6   \
# 0   0.186011  0.023490  0.024300  0.023055  0.021450  0.018630  0.015105
# 1   0.023490  0.358050  0.047850  0.045414  0.041470  0.037352  0.029203
# 2   0.024300  0.047850  0.366197  0.047850  0.042900  0.038640  0.030780
# 3   0.023055  0.045414  0.047850  0.358050  0.042224  0.036685  0.030305
# 4   0.021450  0.041470  0.042900  0.042224  0.316228  0.033488  0.027664
# 5   0.018630  0.037352  0.038640  0.036685  0.033488  0.280179  0.023598
# 6   0.015105  0.029203  0.030780  0.030305  0.027664  0.023598  0.230217
# 7   0.014040  0.028188  0.029700  0.028710  0.025740  0.022770  0.018468
# 8   0.010710  0.021112  0.022680  0.022330  0.020020  0.017066  0.014630
# 9   0.009540  0.018792  0.019800  0.019140  0.017784  0.014904  0.012540
# 10  0.006360  0.012760  0.013680  0.012992  0.011648  0.010304  0.008360
# 11  0.003657  0.007470  0.007866  0.007470  0.006698  0.005925  0.004807
# 12  0.001458  0.002871  0.003078  0.003028  0.002714  0.002318  0.001984
# 13  0.000063  0.000128  0.000135  0.000136  0.000122  0.000101  0.000089
#
#           7         8         9         10        11        12        13
# 0   0.014040  0.010710  0.009540  0.006360  0.003657  0.001458  0.000063
# 1   0.028188  0.021112  0.018792  0.012760  0.007470  0.002871  0.000128
# 2   0.029700  0.022680  0.019800  0.013680  0.007866  0.003078  0.000135
# 3   0.028710  0.022330  0.019140  0.012992  0.007470  0.003028  0.000136
# 4   0.025740  0.020020  0.017784  0.011648  0.006698  0.002714  0.000122
# 5   0.022770  0.017066  0.014904  0.010304  0.005925  0.002318  0.000101
# 6   0.018468  0.014630  0.012540  0.008360  0.004807  0.001984  0.000089
# 7   0.210950  0.013860  0.011880  0.008208  0.004802  0.001879  0.000086
# 8   0.013860  0.166433  0.009408  0.006384  0.003671  0.001512  0.000070
# 9   0.011880  0.009408  0.138924  0.005376  0.003146  0.001274  0.000059
# 10  0.008208  0.006384  0.005376  0.094340  0.002208  0.000864  0.000040
# 11  0.004802  0.003671  0.003146  0.002208  0.054378  0.000505  0.000023
# 12  0.001879  0.001512  0.001274  0.000864  0.000505  0.021095  0.000010
# 13  0.000086  0.000070  0.000059  0.000040  0.000023  0.000010  0.001345

# %%
xlsx_tab=pd.DataFrame(cov)
xlsx_tab.to_excel('LHCb13TeV.xlsx')

# %%
tab=pd.read_excel('30001.xlsx')

# %%
def test():
    cov_arrays = [_ for _ in tab if '_S' in _ and '%' not in _ and 'norm' not in _]
    npts=len(tab['value'])
    covmat=np.zeros((npts,npts))

    if npts!=len(cov_arrays):
        print('Incompatible size for covariance matrix',reaction,idx)
        sys.exit()

    for i in range(len(cov_arrays)):
        covmat[i]=tab[cov_arrays[i]]
test()
# Out:
# [[-2.77555756e-17  0.00000000e+00 -3.46944695e-18  0.00000000e+00
#    0.00000000e+00 -3.46944695e-18  1.73472348e-18  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    2.16840434e-19  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -6.93889390e-18  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -3.46944695e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-3.46944695e-18 -6.93889390e-18  0.00000000e+00 -6.93889390e-18
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -3.46944695e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    4.33680869e-19  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -6.93889390e-18  0.00000000e+00
#    0.00000000e+00  0.00000000e+00 -3.46944695e-18  0.00000000e+00
#   -3.46944695e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -5.55111512e-17 -6.93889390e-18  0.00000000e+00 -3.46944695e-18
#   -3.46944695e-18  3.46944695e-18 -1.73472348e-18  0.00000000e+00
#    0.00000000e+00 -2.71050543e-20]
#  [-3.46944695e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -6.93889390e-18  5.55111512e-17 -3.46944695e-18 -3.46944695e-18
#   -3.46944695e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -1.35525272e-20]
#  [ 1.73472348e-18  0.00000000e+00  0.00000000e+00 -3.46944695e-18
#    0.00000000e+00 -3.46944695e-18  2.77555756e-17 -3.46944695e-18
#   -1.73472348e-18  0.00000000e+00  0.00000000e+00  8.67361738e-19
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -3.46944695e-18 -3.46944695e-18 -3.46944695e-18  2.77555756e-17
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    2.16840434e-19  0.00000000e+00]
#  [ 0.00000000e+00 -3.46944695e-18 -3.46944695e-18 -3.46944695e-18
#   -3.46944695e-18 -3.46944695e-18 -1.73472348e-18  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    3.46944695e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -5.55111512e-17  0.00000000e+00  4.33680869e-19
#    2.16840434e-19  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -1.73472348e-18  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  8.67361738e-19  0.00000000e+00
#    0.00000000e+00  4.33680869e-19  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 2.16840434e-19  0.00000000e+00  4.33680869e-19  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  2.16840434e-19
#    0.00000000e+00  2.16840434e-19  0.00000000e+00  0.00000000e+00
#    3.46944695e-18  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -2.71050543e-20 -1.35525272e-20  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]]

# %%
def test():
    L = np.matrix(np.linalg.cholesky(cov)) #https://en.wikipedia.org/wiki/Cholesky_decomposition
    res =solve_triangular(L, (T/norm-D).transpose(), lower=True)
    chi2b=np.sum(np.square(res))
    print("residuals method: ",chi2b)

# %%
def test():
    cov_arrays = [_ for _ in tab if '_S' in _ and '%' not in _ and 'norm' not in _]
    covmat=np.zeros((4,4))
    for i in range(len([2,3,4,5])):
        idx=[2,3,4,5][i]
#         print(idx)
        for _ in cov_arrays:
            name=_.split('_')
            for __ in name:
                if __.isdigit():
                    nameidx=int(__)
            if idx ==nameidx:
                covmat[i]=tab[_]
    print(covmat)
test()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-ea6cbf740c63> in <module>
#      13                 covmat[i]=tab[_]
#      14     print(covmat)
# ---> 15 test()
#
# <ipython-input-127-ea6cbf740c63> in test()
#      11                     nameidx=int(__)
#      12             if idx ==nameidx:
# ---> 13                 covmat[i]=tab[_]
#      14     print(covmat)
#      15 test()
#
# ValueError: could not broadcast input array from shape (14,) into shape (4,)

# %%
# shifts method -----
ncorr=2
beta=np.array([sys1corr,sys2corr])
alpha=statunc
A=np.diag(np.diag(np.ones((ncorr,ncorr)))) + np.einsum('ki,li,i->kl',beta,beta,1/alpha**2)
B=np.einsum('ki,i,i->k',beta,D-T/norm,1/alpha**2)
r=np.einsum('kl,l->k',np.linalg.inv(A),B)
shift=np.einsum('k,ki->i',r,beta)
res_shifts=(D-shift-T/norm)/alpha
chi2a=np.sum(np.square(res_shifts)) +np.sum(r**2)
print("shifts method:    ", chi2a)

# residuals method -----
L = np.matrix(np.linalg.cholesky(cov)) #https://en.wikipedia.org/wiki/Cholesky_decomposition
res =solve_triangular(L, (T/norm-D).transpose(), lower=True)
chi2b=np.sum(np.square(res))
print("residuals method: ",chi2b)


# covariance method -----
inv_cov = np.matrix(np.linalg.inv(cov)) #inverse of cov
T_m = np.matrix(T)
D_m = np.matrix(D)
chi2c=np.sum((T_m/norm-D_m)*inv_cov*(T_m/norm-D_m).transpose())
print("inv_cov method:   ", chi2c)
