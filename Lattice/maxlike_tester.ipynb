# %%
import sys,os
import numpy as np
path = "/work/JAM/barryp/JAM/fitpack2testing/"
sys.path.insert(0, path)
os.environ['FITPACK']=path

from tools.config import conf,load_config2
from tools.tools  import load, save, checkdir
from fitlib.maxlike import MAXLIKE

conf['verbose']   = 100
conf['bootstrap'] = True
conf['ftol']      = 1e-8

load_config2("analysis-LCS/ccLCS/impact/input.npy")

data=np.load("analysis-LCS/ccLCS/DM_B_R/mcrun/01WGXSQA86XW.msr.npy",allow_pickle=True).item(0)
#--parameters from numpy data
for k in conf['params']:
    if k in data['params']:
        for kk in conf['params'][k]:
             if kk in data['params'][k]:
                conf['params'][k][kk]['value']=data['params'][k][kk]['value']


#--normalizations from numpy data
for k in conf['datasets']:
    if k in data['datasets']:
        for kk in conf['datasets'][k]['norm']:
            if kk in data['datasets'][k]['norm']:
                conf['datasets'][k]['norm'][kk]['value']=data['datasets'][k]['norm'][kk]['value']
                
ml=MAXLIKE()
ml.run2()
# Out:
# pdf g1 N
# pdf g1 a
# pdf g1 b
# pdf uv1 N
# pdf uv1 a
# pdf uv1 b
# pdf dv1 N
# pdf dv1 a
# pdf dv1 b
# pdf db1 N
# pdf db1 a
# pdf db1 b
# pdf ub1 N
# pdf ub1 a
# pdf ub1 b
# pdf s1 N
# pdf s1 a
# pdf s1 b
# pdf sb1 N
# pdf sb1 a
# pdf sb1 b
# pdf sea1 N
# pdf sea1 a
# pdf sea1 b
# pdf sea2 N
# pdf sea2 a
# pdf sea2 b
# pdf-pion g1 N
# pdf-pion g1 a
# pdf-pion g1 b
# pdf-pion ubv1 N
# pdf-pion ubv1 a
# pdf-pion ubv1 b
# pdf-pion ubv1 c
# pdf-pion ubv1 d
# pdf-pion dv1 N
# pdf-pion dv1 a
# pdf-pion dv1 b
# pdf-pion dv1 c
# pdf-pion dv1 d
# pdf-pion u1 N
# pdf-pion u1 a
# pdf-pion u1 b
# pdf-pion db1 N
# pdf-pion db1 a
# pdf-pion db1 b
# pdf-pion s1 N
# pdf-pion s1 a
# pdf-pion s1 b
# pdf-pion sb1 N
# pdf-pion sb1 a
# pdf-pion sb1 b
# p->pi,n lambda
# lat-sys alpha-ccLCS
# lat-sys beta-ccLCS
# lat-sys b0-ccLCS
# lat-sys p0-ccLCS
# lat-sys r0-ccLCS
# lat-sys m0-ccLCS
# lat-sys f0-ccLCS
# lat-sys b1-ccLCS
# lat-sys p1-ccLCS
# lat-sys r1-ccLCS
# lat-sys m1-ccLCS
# lat-sys f1-ccLCS
# lat-sys b2-ccLCS
# lat-sys p2-ccLCS
# lat-sys r2-ccLCS
# lat-sys m2-ccLCS
# lat-sys f2-ccLCS
# loading dy-pion data sets 10001
# loading dy-pion data sets 10002
# loading dy-pion data sets 10003
# 10001 has norm uncertainty
# 10002 has norm uncertainty
# 10003 has norm uncertainty
# loading ln data sets 1000
# loading ln data sets 2000
# 1000 has norm uncertainty
# 2000 has norm uncertainty
# loading ccLCS data sets 327811
# loading ccLCS data sets 335811
# loading ccLCS data sets 341311
# loading ccLCS data sets 341321
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-70b9cc35f593> in <module>
#      33
#      34 ml=MAXLIKE()
# ---> 35 ml.run2()
#
# /work/JAM/barryp/JAM/fitpack2testing/fitlib/maxlike.py in run2(self, flat)
#     490
#     491         self.checklimits()
# --> 492         self.resman=RESMAN(nworkers=self.nworkers,parallel=True,datasets=True)
#     493         self.parman=self.resman.parman
#     494
#
# /work/JAM/barryp/JAM/fitpack2testing/fitlib/resman.py in __init__(self, nworkers, parallel, datasets, parman)
#     184             if 'DYpT'    in conf['datasets']: self.setup_DYpT()
#     185             if 'pITD'    in conf['datasets']: self.setup_pITD()
# --> 186             if 'ccLCS'   in conf['datasets']: self.setup_ccLCS()
#     187
#     188         #--if only idis/pidis/sia/sidis being fit, always turn parallel off
#
# /work/JAM/barryp/JAM/fitpack2testing/fitlib/resman.py in setup_ccLCS(self)
#     527     def setup_ccLCS(self):
#     528         conf['ccLCS tabs']=obslib.ccLCS.reader.READER().load_data_sets('ccLCS')
# --> 529         conf['ccLCS']=obslib.ccLCS.theory.CCLCS()
#     530         conf['ccLCS'].setup_parallel()
#     531         self.ccLCS_res=obslib.ccLCS.residuals.RESIDUALS()
#
# /work/JAM/barryp/JAM/fitpack2testing/obslib/ccLCS/theory.py in __init__(self, pdftype)
#      33         self.m2=0.0
#      34         self.f2=0.0
# ---> 35         self.setup()
#      36
#      37     def setup(self):
#
# /work/JAM/barryp/JAM/fitpack2testing/obslib/ccLCS/theory.py in setup(self)
#      38         self.NU=np.linspace(0.19,4.75,40)
#      39         self.storage00=np.array([self.get_sigma0n(0,_) for _ in self.NU])
# ---> 40         self.storage01=np.array([self.get_sigma0n(1,_) for _ in self.NU])
#      41         self.storage02=np.array([self.get_sigma0n(2,_) for _ in self.NU])
#      42
#
# /work/JAM/barryp/JAM/fitpack2testing/obslib/ccLCS/theory.py in <listcomp>(.0)
#      38         self.NU=np.linspace(0.19,4.75,40)
#      39         self.storage00=np.array([self.get_sigma0n(0,_) for _ in self.NU])
# ---> 40         self.storage01=np.array([self.get_sigma0n(1,_) for _ in self.NU])
#      41         self.storage02=np.array([self.get_sigma0n(2,_) for _ in self.NU])
#      42
#
# /work/JAM/barryp/JAM/fitpack2testing/obslib/ccLCS/theory.py in get_sigma0n(self, n, nu)
#      53         alpha,beta=self.alpha,self.beta
#      54         integrand=lambda x: np.cos(nu*x)*x**alpha*(1-x)**beta*self.jacobipoly(n,x)
# ---> 55         return quad(integrand,0,1)[0]
#      56
#      57     def get_correction(self,z,a,mpi,L,nu):
#
# /opt/conda/lib/python3.8/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     349
#     350     if weight is None:
# --> 351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                        points)
#     353     else:
#
# /opt/conda/lib/python3.8/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /work/JAM/barryp/JAM/fitpack2testing/obslib/ccLCS/theory.py in <lambda>(x)
#      52         #--for real cross section
#      53         alpha,beta=self.alpha,self.beta
# ---> 54         integrand=lambda x: np.cos(nu*x)*x**alpha*(1-x)**beta*self.jacobipoly(n,x)
#      55         return quad(integrand,0,1)[0]
#      56
#
# /work/JAM/barryp/JAM/fitpack2testing/obslib/ccLCS/theory.py in jacobipoly(self, n, x)
#      45         jacobi=0
#      46         for j in range(n+1):
# ---> 47             omega=binom(n,j)*(-1)**j/factorial(n)*gamma(alpha+n+1)*gamma(alpha+beta+n+j+1)/gamma(alpha+beta+n+1)/gamma(alpha+j+1)
#      48             jacobi+=omega*x**j
#      49         return jacobi
#
# KeyboardInterrupt:
